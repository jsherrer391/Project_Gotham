# %%
import os
import requests
import json
import pandas as pd
from dotenv import load_dotenv
import alpaca_trade_api as tradeapi
from MCForecastTools import MCSimulation
import questionary
import datetime
# %matplotlib inline

# %%
# Load the environment variables from the .env file
#by calling the load_dotenv function
load_dotenv()
# Out:
# True

# %%
# Set the variables for the Alpaca API and secret keys
alpaca_api_key = os.getenv("ALPACA_API_KEY")
alpaca_secret_key = os.getenv("ALPACA_SECRET_KEY")
# Create the Alpaca tradeapi.REST object
# YOUR CODE HERE
alpaca = tradeapi.REST(
            alpaca_api_key,
            alpaca_secret_key,
            api_version = "v2")

# %%
#tickers= questionary.text(f"What ETFs do you want to run the Monte Carlo Simulation on?"
                            #"Enter tickers in the following format", default=["SPY", "AGG"]).ask()

#print(f"Preparing 3 years of historical data for requested tickers... ")
                          
timeframe = "1D"

today = str(datetime.datetime.today()).split()[0]

three_years_ago= str(datetime.datetime.today()- datetime.timedelta(days=1095)).split()[0]

start_date= pd.Timestamp(three_years_ago, tz="America/New_York").isoformat()

end_date= pd.Timestamp(today, tz="America/New_York").isoformat()
                       
limit_rows=1000
                           
tickers=["AGG", "SPY"]
# Out:
#   File "<ipython-input-25-5c4927e9a458>", line 4
#     print(f"Preparing 3 years of historical data for requested tickers... ")
#         ^
# SyntaxError: invalid syntax

# %%
alpaca_df= alpaca.get_barset(
               tickers,
               timeframe,
               limit= limit_rows,
               start = start_date,
               end = end_date
).df

display(alpaca_df.head())
display(alpaca_df.tail())
# Out:
#                               AGG                                         \
#                              open     high       low    close     volume
# time
# 2018-08-13 00:00:00-04:00  106.16  106.300  106.1501  106.285  2558386.0
# 2018-08-14 00:00:00-04:00  106.30  106.330  106.1600  106.190  3862629.0
# 2018-08-15 00:00:00-04:00  106.29  106.440  106.2500  106.335  4093893.0
# 2018-08-16 00:00:00-04:00  106.38  106.420  106.2400  106.390  2135827.0
# 2018-08-17 00:00:00-04:00  106.43  106.545  106.3800  106.460  1915186.0
#
#                               SPY
#                              open      high       low   close    volume
# time
# 2018-08-13 00:00:00-04:00  283.47  284.1600  281.7700  282.05  49247799
# 2018-08-14 00:00:00-04:00  282.92  284.1700  282.4833  283.86  32906829
# 2018-08-15 00:00:00-04:00  282.38  282.5400  280.1600  281.76  76384638
# 2018-08-16 00:00:00-04:00  283.40  285.0400  283.3600  284.10  49048421
# ...

# %%
def get_user_input_MC():
    """Prompt dialog to dynamically get the data needed to run personalised Monte Carlo Simulations.

    Returns:
        Returns the user's input needed to run MC Simulation.
    """

    weights= questionary.text("How do you want to weigh your portfolio? Enter percentage weights 
                              "separated by comas in the following format i.e [.4,.6]",
                              default= "[]").ask()
    num_simulation= questionary.select("How many simulations would you like to run?", choices=[250, 500, 1000]).ask()
    num_of_years= questionary.text("How many years of cumulative returns would you like to forecast?").ask()
   
    x = data.loc[x]
    weights = float(weights)
    num_simulation = int(num_simulation)
    num_of_years = int(num_of_years)

    return x, weights, num_simulation, num_of_years
# Out:
#   File "<ipython-input-6-9d80234b81c6>", line 8
#     weights= questionary.text("How do you want to weigh your portfolio? Enter percentage weights
#                                                                                                  ^
# SyntaxError: EOL while scanning string literal

# %%
""" Runs personalised Monte Carlo Simulation per parameters supplied by the user """
MCSim = MCSimulation(portfolio_data, 
                      weights,
                      num_simulation ,
                     num_trading_days = 252 * num_of_years)
